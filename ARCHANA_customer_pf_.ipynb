# %%
import pandas as pd

# %%
customer_df=pd.read_csv("/content/drive/MyDrive/Assignment-1_Data.csv",sep=";")
# Out:
# <ipython-input-2-05a330c9ddfc>:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   customer_df=pd.read_csv("/content/drive/MyDrive/Assignment-1_Data.csv",sep=";")

# %%
customer_df
# Out:
#         BillNo                             Itemname  Quantity  \
# 0       536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365                  WHITE METAL LANTERN         6
# 2       536365       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...                                  ...       ...
# 522059  581587          PACK OF 20 SPACEBOY NAPKINS        12
# 522060  581587          CHILDREN'S APRON DOLLY GIRL         6
# 522061  581587         CHILDRENS CUTLERY DOLLY GIRL         4
# 522062  581587      CHILDRENS CUTLERY CIRCUS PARADE         4
# 522063  581587         BAKING SET 9 PIECE RETROSPOT         3
#
#                     Date Price  CustomerID         Country
# 0       01.12.2010 08:26  2,55     17850.0  United Kingdom
# 1       01.12.2010 08:26  3,39     17850.0  United Kingdom
# ...

# %%
customer_df.head(10)
# Out:
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
# 5  536365         SET 7 BABUSHKA NESTING BOXES         2  01.12.2010 08:26
# 6  536365    GLASS STAR FROSTED T-LIGHT HOLDER         6  01.12.2010 08:26
# 7  536366               HAND WARMER UNION JACK         6  01.12.2010 08:28
# 8  536366            HAND WARMER RED POLKA DOT         6  01.12.2010 08:28
# 9  536367        ASSORTED COLOUR BIRD ORNAMENT        32  01.12.2010 08:34
#
#   Price  CustomerID         Country
# 0  2,55     17850.0  United Kingdom
# 1  3,39     17850.0  United Kingdom
# ...

# %%
customer_df.describe()
# Out:
#             Quantity     CustomerID
# count  522064.000000  388023.000000
# mean       10.090435   15316.931710
# std       161.110525    1721.846964
# min     -9600.000000   12346.000000
# 25%         1.000000   13950.000000
# 50%         3.000000   15265.000000
# 75%        10.000000   16837.000000
# max     80995.000000   18287.000000

# %%
customer_df.max()
# Out:
# <ipython-input-6-649c9a5f9ebf>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   customer_df.max()
# Quantity                 80995
# Date          31.10.2011 17:19
# Price                    99,96
# CustomerID             18287.0
# Country            Unspecified
# dtype: object

# %%
customer_df.count()
# Out:
# BillNo        522064
# Itemname      520609
# Quantity      522064
# Date          522064
# Price         522064
# CustomerID    388023
# Country       522064
# dtype: int64

# %%
customer_df.columns
# Out:
# Index(['BillNo', 'Itemname', 'Quantity', 'Date', 'Price', 'CustomerID',
#        'Country'],
#       dtype='object')

# %%
customer_df.isnull().sum()
# Out:
# BillNo             0
# Itemname        1455
# Quantity           0
# Date               0
# Price              0
# CustomerID    134041
# Country            0
# dtype: int64

# %%
customer_df.dropna(subset=['Itemname'], inplace=True)
customer_df.dropna(subset=['CustomerID'],inplace=True)

# %%
customer_df.isnull().sum()
# Out:
# BillNo        0
# Itemname      0
# Quantity      0
# Date          0
# Price         0
# CustomerID    0
# Country       0
# dtype: int64

# %%
###What is the highest and lowest purchase product in the customer df?

# %%
dd=customer_df.groupby("Itemname")["Quantity"].max().reset_index()
dd.head(10)
# Out:
#                               Itemname  Quantity
# 0               10 COLOUR SPACEBOY PEN       288
# 1           12 COLOURED PARTY BALLOONS       100
# 2            12 DAISY PEGS IN WOOD BOX        24
# 3            12 EGG HOUSE PAINTED WOOD         4
# 4         12 HANGING EGGS HAND PAINTED        10
# 5     12 IVORY ROSE PEG PLACE SETTINGS        36
# 6      12 MESSAGE CARDS WITH ENVELOPES        60
# 7        12 PENCIL SMALL TUBE WOODLAND       384
# 8  12 PENCILS SMALL TUBE RED RETROSPOT       768
# 9          12 PENCILS SMALL TUBE SKULL       480

# %%
customer_df.groupby("Itemname")["Quantity"].min().reset_index()
# Out:
#                               Itemname  Quantity
# 0               10 COLOUR SPACEBOY PEN         1
# 1           12 COLOURED PARTY BALLOONS         1
# 2            12 DAISY PEGS IN WOOD BOX         1
# 3            12 EGG HOUSE PAINTED WOOD         1
# 4         12 HANGING EGGS HAND PAINTED         1
# ...                                ...       ...
# 3841   ZINC T-LIGHT HOLDER STARS SMALL         1
# 3842     ZINC TOP  2 DOOR WOODEN SHELF         1
# 3843  ZINC WILLIE WINKIE  CANDLE STICK         1
# 3844       ZINC WIRE KITCHEN ORGANISER         1
# 3845  ZINC WIRE SWEETHEART LETTER TRAY         1
#
# [3846 rows x 2 columns]

# %%
##idmax()will return the top of the value

# %%
max_quality=customer_df.groupby("Itemname")["Quantity"].idxmax().reset_index()

# %%
max_quality.head(10)
# Out:
#                               Itemname  Quantity
# 0               10 COLOUR SPACEBOY PEN    287851
# 1           12 COLOURED PARTY BALLOONS    166496
# 2            12 DAISY PEGS IN WOOD BOX     65883
# 3            12 EGG HOUSE PAINTED WOOD     71009
# 4         12 HANGING EGGS HAND PAINTED    453359
# 5     12 IVORY ROSE PEG PLACE SETTINGS    215502
# 6      12 MESSAGE CARDS WITH ENVELOPES     28806
# 7        12 PENCIL SMALL TUBE WOODLAND     87446
# 8  12 PENCILS SMALL TUBE RED RETROSPOT    114954
# 9          12 PENCILS SMALL TUBE SKULL    280557

# %%
mini_quality=customer_df.groupby("Itemname")["Quantity"].idxmin().reset_index()
mini_quality.head(10)
# Out:
#                               Itemname  Quantity
# 0               10 COLOUR SPACEBOY PEN     38563
# 1           12 COLOURED PARTY BALLOONS    208741
# 2            12 DAISY PEGS IN WOOD BOX       569
# 3            12 EGG HOUSE PAINTED WOOD     54558
# 4         12 HANGING EGGS HAND PAINTED    483034
# 5     12 IVORY ROSE PEG PLACE SETTINGS      7628
# 6      12 MESSAGE CARDS WITH ENVELOPES      3743
# 7        12 PENCIL SMALL TUBE WOODLAND      7891
# 8  12 PENCILS SMALL TUBE RED RETROSPOT      4043
# 9          12 PENCILS SMALL TUBE SKULL      5099

# %%
mini_quality.tail(10)
# Out:
#                               Itemname  Quantity
# 3836          ZINC STAR T-LIGHT HOLDER    198250
# 3837         ZINC SWEETHEART SOAP DISH    169449
# 3838  ZINC SWEETHEART WIRE LETTER RACK    230421
# 3839    ZINC T-LIGHT HOLDER STAR LARGE    171350
# 3840   ZINC T-LIGHT HOLDER STARS LARGE    194458
# 3841   ZINC T-LIGHT HOLDER STARS SMALL    449580
# 3842     ZINC TOP  2 DOOR WOODEN SHELF     17887
# 3843  ZINC WILLIE WINKIE  CANDLE STICK       128
# 3844       ZINC WIRE KITCHEN ORGANISER    275969
# 3845  ZINC WIRE SWEETHEART LETTER TRAY    161170

# %%
##top value based on quantity?
##nlargest() method is used to retrieve the top N largest elements from a Series or DataFrame

# %%
customer_df.nlargest(5, 'Quantity').reset_index()
# Out:
#     index  BillNo                           Itemname  Quantity  \
# 0  520583  581483        PAPER CRAFT , LITTLE BIRDIE     80995
# 1   59999  541431     MEDIUM CERAMIC TOP STORAGE JAR     74215
# 2  483371  578841     ASSTD DESIGN 3D PAPER STICKERS     12540
# 3  405138  573008  WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
# 4  198929  554868               SMALL POPCORN HOLDER      4300
#
#                Date  Price  CustomerID         Country
# 0  09.12.2011 09:15   2.08     16446.0  United Kingdom
# 1  18.01.2011 10:01   1.04     12346.0  United Kingdom
# 2  25.11.2011 15:57   0.00     13256.0  United Kingdom
# 3  27.10.2011 12:26   0.21     12901.0  United Kingdom
# 4  27.05.2011 10:52   0.72     13135.0  United Kingdom

# %%
top_value = customer_df.nlargest(5, 'Quantity').reset_index()
top_value
# Out:
#     index  BillNo                           Itemname  Quantity  \
# 0  520583  581483        PAPER CRAFT , LITTLE BIRDIE     80995
# 1   59999  541431     MEDIUM CERAMIC TOP STORAGE JAR     74215
# 2  483371  578841     ASSTD DESIGN 3D PAPER STICKERS     12540
# 3  405138  573008  WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
# 4  198929  554868               SMALL POPCORN HOLDER      4300
#
#                Date Price  CustomerID         Country
# 0  09.12.2011 09:15  2,08     16446.0  United Kingdom
# 1  18.01.2011 10:01  1,04     12346.0  United Kingdom
# 2  25.11.2011 15:57     0     13256.0  United Kingdom
# 3  27.10.2011 12:26  0,21     12901.0  United Kingdom
# 4  27.05.2011 10:52  0,72     13135.0  United Kingdom

# %%
columns = ['BillNo','reg_date']
columns
# Out:
# ['BillNo', 'reg_date']

# %%
#print(customer_df["Country"].unique())

#print(customer_df["Itemname"].unique())
#print(customer_df["Quantity"].unique())
#print(customer_df["Date"].unique())
#print(customer_df["Price"].unique())
print(customer_df["CustomerID"].unique())
# Out:
# [17850. 13047. 12583. ... 13298. 14569. 12713.]

# %%
##Count() is what tells us the total number of rows or you can say datapoints for that column
##Value_counts() function of pandas counts the number of occurrences of each value
##unique() function returns the unique values that occur at least once.

# %%
customer_df['Itemname'].value_counts().to_frame()
# Out:
#                                     Itemname
# WHITE HANGING HEART T-LIGHT HOLDER      1976
# REGENCY CAKESTAND 3 TIER                1643
# JUMBO BAG RED RETROSPOT                 1591
# ASSORTED COLOUR BIRD ORNAMENT           1391
# PARTY BUNTING                           1369
# ...                                      ...
# OCEAN STRIPE HAMMOCK                       1
# PAINTED HEART WREATH WITH BELL             1
# WEEKEND BAG VINTAGE ROSE PAISLEY           1
# WRAP  PINK FLOCK                           1
# PAPER CRAFT , LITTLE BIRDIE                1
#
# [3846 rows x 1 columns]

# %%
###which product was frequently buy?

# %%
customer_df['Itemname'].value_counts().idxmax()
# Out:
# 'WHITE HANGING HEART T-LIGHT HOLDER'

# %%
##another method

# %%
customer_df['Itemname'].value_counts().index[0]
# Out:
# 'WHITE HANGING HEART T-LIGHT HOLDER'

# %%
##find average value of customer using quantity?

# %%
customer_df.groupby('CustomerID')['Quantity'].mean().head(5)
# Out:
# CustomerID
# 12346.0    74215.000000
# 12347.0       13.505495
# 12349.0        8.643836
# 12350.0       11.588235
# 12352.0        6.305882
# Name: Quantity, dtype: float64

# %%
customer_df.mode()
# Out:
#    BillNo                            Itemname  Quantity              Date  \
# 0  576339  WHITE HANGING HEART T-LIGHT HOLDER         1  14.11.2011 15:27
#
#    Price  CustomerID         Country
# 0   1.25     17841.0  United Kingdom

# %%
customer_df['Itemname'].value_counts().idxmin()
# Out:
# 'LETTER "T" BLING KEY RING'

# %%
customer_df["BillNo"].value_counts().idxmax()
# Out:
# 576339

# %%
##find average value of customer using price?

# %%
customer_df['Price'] = customer_df['Price'].str.replace(',', '.').astype(float)

# %%
customer_df.groupby('CustomerID')['Price'].mean()
# Out:
# CustomerID
# 12346.0     1.040000
# 12347.0     2.644011
# 12349.0     8.289041
# 12350.0     3.841176
# 12352.0    15.930706
#              ...
# 18280.0     4.765000
# 18281.0     5.622857
# 18282.0     5.199167
# 18283.0     1.614987
# 18287.0     1.493571
# Name: Price, Length: 4297, dtype: float64

# %%
#the average value on each columns

# %%
customer_df.mean()
# Out:
# <ipython-input-46-caf7d0bd72f3>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   customer_df.mean()
# Quantity         12.892140
# Price             3.079258
# CustomerID    15316.931710
# dtype: float64

# %%
pd.to_datetime(customer_df["Date"]).dt.year
# Out:
# 0         2010
# 1         2010
# 2         2010
# 3         2010
# 4         2010
#           ...
# 522059    2011
# 522060    2011
# 522061    2011
# 522062    2011
# 522063    2011
# Name: Date, Length: 388023, dtype: int64

# %%
customer_df
# Out:
#         BillNo                             Itemname  Quantity  \
# 0       536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365                  WHITE METAL LANTERN         6
# 2       536365       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...                                  ...       ...
# 522059  581587          PACK OF 20 SPACEBOY NAPKINS        12
# 522060  581587          CHILDREN'S APRON DOLLY GIRL         6
# 522061  581587         CHILDRENS CUTLERY DOLLY GIRL         4
# 522062  581587      CHILDRENS CUTLERY CIRCUS PARADE         4
# 522063  581587         BAKING SET 9 PIECE RETROSPOT         3
#
#                     Date Price  CustomerID         Country
# 0       01.12.2010 08:26  2,55     17850.0  United Kingdom
# 1       01.12.2010 08:26  3,39     17850.0  United Kingdom
# ...

# %%
customer_df.head(20)
# Out:
#     BillNo                             Itemname  Quantity              Date  \
# 0   536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1   536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2   536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3   536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4   536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
# 5   536365         SET 7 BABUSHKA NESTING BOXES         2  01.12.2010 08:26
# 6   536365    GLASS STAR FROSTED T-LIGHT HOLDER         6  01.12.2010 08:26
# 7   536366               HAND WARMER UNION JACK         6  01.12.2010 08:28
# 8   536366            HAND WARMER RED POLKA DOT         6  01.12.2010 08:28
# 9   536367        ASSORTED COLOUR BIRD ORNAMENT        32  01.12.2010 08:34
# 10  536367            POPPY'S PLAYHOUSE BEDROOM         6  01.12.2010 08:34
# ...

# %%
customer_df['Date'] = pd.to_datetime(customer_df["Date"])

# %%
customer_df['customer_Date'] = pd.to_datetime(customer_df["Date"]).dt.date
customer_df['Time'] = pd.to_datetime(customer_df["Date"]).dt.time

# %%
customer_df
# Out:
#         BillNo                             Itemname  Quantity  \
# 0       536365   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365                  WHITE METAL LANTERN         6
# 2       536365       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...                                  ...       ...
# 522059  581587          PACK OF 20 SPACEBOY NAPKINS        12
# 522060  581587          CHILDREN'S APRON DOLLY GIRL         6
# 522061  581587         CHILDRENS CUTLERY DOLLY GIRL         4
# 522062  581587      CHILDRENS CUTLERY CIRCUS PARADE         4
# 522063  581587         BAKING SET 9 PIECE RETROSPOT         3
#
#                     Date  Price  CustomerID         Country customer_Date  \
# 0       01.12.2010 08:26   2.55     17850.0  United Kingdom    2010-01-12
# ...

# %%
#What is the average purchase amount per customer?

# %%
customer_df['% of total'].head(10)
# Out:
# 0    0.003462
# 1    0.003462
# 2    0.004616
# 3    0.003462
# 4    0.003462
# 5    0.001154
# 6    0.003462
# 7    0.003462
# 8    0.003462
# 9    0.023005
# Name: % of total, dtype: float64

# %%
len("CustomerID")
# Out:
# 10

# %%
###  what are the products customers will buy and how manytime ??

# %%
customer_purchase_counts= customer_df.groupby(['CustomerID', 'Itemname']).size().reset_index(name='purchase_count')

customer_purchase_counts
# Out:
#         CustomerID                           Itemname  purchase_count
# 0          12346.0     MEDIUM CERAMIC TOP STORAGE JAR               1
# 1          12347.0       3D DOG PICTURE PLAYING CARDS               5
# 2          12347.0           3D SHEET OF CAT STICKERS               1
# 3          12347.0           3D SHEET OF DOG STICKERS               1
# 4          12347.0        60 TEATIME FAIRY CAKE CASES               3
# ...            ...                                ...             ...
# 263262     18287.0  STAR T-LIGHT HOLDER WILLIE WINKIE               1
# 263263     18287.0             STRAWBERRY BATH SPONGE               1
# 263264     18287.0     STRAWBERRY CERAMIC TRINKET BOX               1
# 263265     18287.0       SWISS CHALET TREE DECORATION               2
# 263266     18287.0  TREE T-LIGHT HOLDER WILLIE WINKIE               1
#
# [263267 rows x 3 columns]

# %%
customer_purchase_counts.max()
# Out:
# CustomerID                                 18287.0
# Itemname          ZINC WIRE SWEETHEART LETTER TRAY
# purchase_count                                  64
# dtype: object

# %%
#how many times a per customer has purchased a specific product?

# %%
customer_id = 17850
product_name = 'CREAM CUPID HEARTS COAT HANGER'

count_tv = customer_df[(customer_df['CustomerID'] == customer_id) &
                               (customer_df['Itemname'] == product_name)].reset_index()

# %%
count_tv
# Out:
#     index  BillNo                        Itemname  Quantity              Date  \
# 0       2  536365  CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 1      51  536373  CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 09:02
# 2      68  536375  CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 09:32
# 3     271  536396  CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 10:51
# 4     409  536406  CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 11:33
# 5    3146  536609  CREAM CUPID HEARTS COAT HANGER         6  02.12.2010 09:41
# 6    3178  536612  CREAM CUPID HEARTS COAT HANGER         6  02.12.2010 09:44
# 7    3377  536628  CREAM CUPID HEARTS COAT HANGER         6  02.12.2010 10:54
# 8    3395  536630  CREAM CUPID HEARTS COAT HANGER         6  02.12.2010 10:56
# 9    3759  536685  CREAM CUPID HEARTS COAT HANGER         6  02.12.2010 12:23
# 10   3774  536690  CREAM CUPID HEARTS COAT HANGER         6  02.12.2010 12:25
# ...

# %%
##how many times a per customer buy product in that shop?

# %%
DF=customer_df.loc[customer_df["CustomerID"]==12680.0]
DF["CustomerID"].value_counts()
# Out:
# 12680.0    52
# Name: CustomerID, dtype: int64

# %%
DF.shape
# Out:
# (0, 7)

# %%
###What is the total revenue for a specific time period?

# %%
start_date = "01.12.2010 08:26"
end_date = "01.12.2010 08:34"

filtered_df = customer_df[(customer_df['Date'] >= start_date) & (customer_df['Date'] <= end_date)]

# %%
total_revenue = filtered_df['Price'].sum()
print(f' ${total_revenue}')
# Out:
#  $108.41000000000001

# %%
###unique customers made a purchase in a given month?

# %%
target_month = "09.12.2011 12:50"

target_month_purchases = customer_df[customer_df['Date'] == target_month]

unique_customers = target_month_purchases['CustomerID'].reset_index()

print(unique_customers)
# Out:
#      index  CustomerID
# 0   522049     12680.0
# 1   522050     12680.0
# 2   522051     12680.0
# 3   522052     12680.0
# 4   522053     12680.0
# 5   522054     12680.0
# 6   522055     12680.0
# 7   522056     12680.0
# 8   522057     12680.0
# 9   522058     12680.0
# 10  522059     12680.0
# 11  522060     12680.0
# 12  522061     12680.0
# 13  522062     12680.0
# 14  522063     12680.0

# %%
##find out an overall customer list in a specific country?

# %%
country_product_counts = customer_df.groupby('Country')['CustomerID'].nunique().reset_index()
print(country_product_counts)
# Out:
#                  Country  CustomerID
# 0              Australia           9
# 1                Austria          11
# 2                Bahrain           2
# 3                Belgium          25
# 4                 Brazil           1
# 5                 France          87
# 6                Germany          94
# 7                 Greece           4
# 8                Iceland           1
# 9                 Israel           3
# 10                 Italy          14
# 11                 Japan           8
# 12               Lebanon           1
# 13             Lithuania           1
# 14                 Malta           2
# 15           Netherlands           9
# 16                Norway          10
# 17                Poland           6
# 18              Portugal          19
# 19                   RSA           1
# 20          Saudi Arabia           1
# 21             Singapore           1
# 22                 Spain          30
# 23                Sweden           8
# ...

# %%
## which country customer buy more product in that shop?

# %%
max_products_country = country_product_counts[country_product_counts['CustomerID'] == country_product_counts['CustomerID'].max()]

print("Country with the most products purchased:")
print(max_products_country)
# Out:
# Country with the most products purchased:
#            Country  CustomerID
# 27  United Kingdom        3921

# %%
customer_df.head(2)
# Out:
#    BillNo                            Itemname  Quantity              Date  \
# 0  536365  WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                 WHITE METAL LANTERN         6  01.12.2010 08:26
#
#    Price  CustomerID         Country
# 0   2.55     17850.0  United Kingdom
# 1   3.39     17850.0  United Kingdom

# %%
customer_df.size
# Out:
# 2716161
